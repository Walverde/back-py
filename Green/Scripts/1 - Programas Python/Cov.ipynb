# %%
import requests
import pandas as pd

# %%
API_BRASIL_IO = "https://brasil.io/api/dataset/covid19/caso_full/data"

# %%
resposta = requests.get(API_BRASIL_IO)
if resposta.ok:
    dados = resposta.json()

# %%
dados
# Out:
# {'count': 294907,
#  'next': 'https://brasil.io/api/dataset/covid19/caso_full/data/?page=2',
#  'previous': None,
#  'results': [{'city': 'Acrelândia',
#    'city_ibge_code': 1200013,
#    'date': '2020-07-01',
#    'epidemiological_week': 27,
#    'estimated_population_2019': 15256,
#    'is_last': True,
#    'is_repeated': False,
#    'last_available_confirmed': 194,
#    'last_available_confirmed_per_100k_inhabitants': 1271.63083,
#    'last_available_date': '2020-07-01',
#    'last_available_death_rate': 0.0155,
#    'last_available_deaths': 3,
#    'new_confirmed': 2,
#    'new_deaths': 0,
#    'order_for_place': 95,
#    'place_type': 'city',
#    'state': 'AC'},
#   {'city': 'Assis Brasil',
#    'city_ibge_code': 1200054,
#    'date': '2020-07-01',
#    'epidemiological_week': 27,
#    'estimated_population_2019': 7417,
#    'is_last': True,
#    'is_repeated': False,
#    'last_available_confirmed': 186,
#    'last_available_confirmed_per_100k_inhabitants': 2507.75246,
# ...

# %%
type(dados)
# Out:
# dict

# %%
resultados = dados ['results']

# %%
type(resultados)
# Out:
# list

# %%
dados
# Out:
# {'count': 289563,
#  'next': 'https://brasil.io/api/dataset/covid19/caso_full/data/?page=2',
#  'previous': None,
#  'results': [{'city': 'Acrelândia',
#    'city_ibge_code': 1200013,
#    'date': '2020-06-30',
#    'epidemiological_week': 27,
#    'estimated_population_2019': 15256,
#    'is_last': False,
#    'is_repeated': True,
#    'last_available_confirmed': 192,
#    'last_available_confirmed_per_100k_inhabitants': 1258.52124,
#    'last_available_date': '2020-06-29',
#    'last_available_death_rate': 0.0156,
#    'last_available_deaths': 3,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'order_for_place': 94,
#    'place_type': 'city',
#    'state': 'AC'},
#   {'city': 'Assis Brasil',
#    'city_ibge_code': 1200054,
#    'date': '2020-06-30',
#    'epidemiological_week': 27,
#    'estimated_population_2019': 7417,
#    'is_last': False,
#    'is_repeated': True,
#    'last_available_confirmed': 174,
#    'last_available_confirmed_per_100k_inhabitants': 2345.96198,
# ...

# %%
len(resultados)
# Out:
# 1000

# %%
for resultado in resultados:
    if resultado ['city'] == 'Acrelândia':
        print(resultado)
# Out:
# {'city': 'Acrelândia', 'city_ibge_code': 1200013, 'date': '2020-06-30', 'epidemiological_week': 27, 'estimated_population_2019': 15256, 'is_last': False, 'is_repeated': True, 'last_available_confirmed': 192, 'last_available_confirmed_per_100k_inhabitants': 1258.52124, 'last_available_date': '2020-06-29', 'last_available_death_rate': 0.0156, 'last_available_deaths': 3, 'new_confirmed': 0, 'new_deaths': 0, 'order_for_place': 94, 'place_type': 'city', 'state': 'AC'}

# %%
resl = pd.DataFrame(resultados)

# %%
resl
# Out:
#                     city  city_ibge_code        date  epidemiological_week  \
# 0             Acrelândia       1200013.0  2020-06-30                    27
# 1           Assis Brasil       1200054.0  2020-06-30                    27
# 2              Brasiléia       1200104.0  2020-06-30                    27
# 3                 Bujari       1200138.0  2020-06-30                    27
# 4               Capixaba       1200179.0  2020-06-30                    27
# ..                   ...             ...         ...                   ...
# 995  Leopoldo de Bulhões       5212303.0  2020-06-30                    27
# 996             Luziânia       5212501.0  2020-06-30                    27
# 997            Mara Rosa       5212808.0  2020-06-30                    27
# 998            Matrinchã       5212956.0  2020-06-30                    27
# 999          Maurilândia       5213004.0  2020-06-30                    27
#
#      estimated_population_2019  is_last  is_repeated  \
# ...
