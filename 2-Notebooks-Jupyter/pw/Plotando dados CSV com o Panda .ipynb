# %% [markdown]
# # Plotando dados CSV com o Pandas e matplolib

# %%
#BIBLIOTECAS PADRAO QUE ESTAO SENDO ULTILIZADAS EM TODOS OS PROJETOS. (SO COPIAR E COLAR E DESCOMENTAR AS NESCESSARIAS)


from pymongo import MongoClient
#import numpy as np
#import pymongo import mongo_
#from pandas.io.json import json_normalize
#import pandas as pd
import matplotlib.pyplot as plt
import json
import pprint
#import warnings.filterwarnings('ignore')

# %% [markdown]
# # Importando Pandas com dicionario auxiliar

# %%
#https://www.youtube.com/watch?v=an54pc9BW4I

import pandas as pd
dc = {'Nome':['Jão','boy','jhow','sam','mar','mary'],
     'Nota':[1,2,3,4,5,6],
     'Aprovado':['Nao','Nope','Necas','necas de pitibiriba','laje','nem'],
     'Local':['Cwb','Pinhais','SJP','4//','tamadare','araucaria'],
     'Class':['01','02','03','04','05','06'],
     'Matricula':['Pew01','Pew02','Pew03','Pew04','Pew05','Pew06']}

# %% [markdown]
# # Comando para explorar o Data Frame

# %%
#Criando data Frame: ptdc, a partir de do dicionario: dc
dfdc = pd.DataFrame (dc)

# %%
#Imprimindo DataFrame
print (dfdc)
#tambem pode ser usado o compnado head(), exemplo abaixo.
# Out:
#    Nome  Nota             Aprovado      Local Class Matricula
# 0   Jão     1                  Nao        Cwb    01     Pew01
# 1   boy     2                 Nope    Pinhais    02     Pew02
# 2  jhow     3                Necas        SJP    03     Pew03
# 3   sam     4  necas de pitibiriba        4//    04     Pew04
# 4   mar     5                 laje   tamadare    05     Pew05
# 5  mary     6                  nem  araucaria    06     Pew06

# %%
#Exemplo de print com Head
dfdc.head()
# Out:
#    Nome  Nota             Aprovado     Local Class Matricula
# 0   Jão     1                  Nao       Cwb    01     Pew01
# 1   boy     2                 Nope   Pinhais    02     Pew02
# 2  jhow     3                Necas       SJP    03     Pew03
# 3   sam     4  necas de pitibiriba       4//    04     Pew04
# 4   mar     5                 laje  tamadare    05     Pew05

# %%
#Tambem se pode imprimir o dc, porem não formatado como Dataframe
print (dc)
# Out:
# {'Nome': ['Jão', 'boy', 'jhow', 'sam', 'mar', 'mary'], 'Nota': [1, 2, 3, 4, 5, 6], 'Aprovado': ['Nao', 'Nope', 'Necas', 'necas de pitibiriba', 'laje', 'nem'], 'Local': ['Cwb', 'Pinhais', 'SJP', '4//', 'tamadare', 'araucaria'], 'Class': ['01', '02', '03', '04', '05', '06'], 'Matricula': ['Pew01', 'Pew02', 'Pew03', 'Pew04', 'Pew05', 'Pew06']}

# %%
# SHAPE: Extraindo informacao de linhas e colunos do DataFrame
dfdc.shape
# Out:
# (6, 6)

# %%
# DESCRIBE: printa uma pequena analise, do Dataframe, como: Contagem, media, desvio padrao,minimo, percentil;25%;50%,75%, maximo
dfdc.describe()
# Out:
#            Nota
# count  6.000000
# mean   3.500000
# std    1.870829
# min    1.000000
# 25%    2.250000
# 50%    3.500000
# 75%    4.750000
# max    6.000000

# %% [markdown]
# # Filtrando dados com o Pandas

# %% [raw]
# FILTRANDO LINHAS

# %%
# Usando essa linha de compando, posso filtrar somente a coluna desejada
dfdc['Nome']
# Out:
# 0     Jão
# 1     boy
# 2    jhow
# 3     sam
# 4     mar
# 5    mary
# Name: Nome, dtype: object

# %%
# Usando essa linha de compando, posso filtrar as colunas desejadas
dfdc[["Nome","Nota"]]
# Out:
#    Nome  Nota
# 0   Jão     1
# 1   boy     2
# 2  jhow     3
# 3   sam     4
# 4   mar     5
# 5  mary     6

# %% [raw]
# LOC: FILTRANDO LINHAS

# %%
#Filtrando apenas linhas, usado o Indicie atribuido pela Biblioteca Pandas.
dfdc.loc[[1,2]]
# Out:
#    Nome  Nota Aprovado    Local Class Matricula
# 1   boy     2     Nope  Pinhais    02     Pew02
# 2  jhow     3    Necas      SJP    03     Pew03

# %%
#Filtrando feixa de linhas, usado :
dfdc.loc[3:5]
# Out:
#    Nome  Nota             Aprovado      Local Class Matricula
# 3   sam     4  necas de pitibiriba        4//    04     Pew04
# 4   mar     5                 laje   tamadare    05     Pew05
# 5  mary     6                  nem  araucaria    06     Pew06

# %%
#Filtrando uma linha usado uma informacao
dfdc.loc[dfdc[]]

# %% [markdown]
# #  Lendo dados com o pandas e plotando com Matlabplot

# %%
#Lendo daods contido no diretorio: C:/Users/Walgreen.melo/Desktop/Pydata/Green/Scripts/pw/Dados/dados.csv, 
#PS: AS BARRA FORAM INVERTIDOS PARA QUE FUNCIONE
dat = pd.read_csv('C:/Users/Walgreen.melo/Desktop/Pydata/Green/Scripts/pw/Dados/dados.csv')

# %%
# Printando dados do data freme: dat
# Entre (), pode-se colocar a quantidade de linhas que se deseja printar.
# Numero em negrito ao lado, foram criado automaticamente pelo pandas; chamado de Id de linha. 
#https://www.youtube.com/watch?v=cd6eU5GV_8o
dat.head(20)
# Out:
#     Time  VARMS  VBRMS  VCRMS  IARMS  IBRMS  ICRMS  VABRMS  VBCRMS  VCARMS  \
# 0    128    130    130      2      2     44    224     225     223     224
# 1    128    130    130      2      2     44    224     225     223     224
# 2    128    130    130      2      2     42    224     225     223     224
# 3    129    130    130      2      2     41    224     225     224     224
# 4    128    130    130      2      2     42    224     225     223     224
# 5    128    130    130      2      2     41    225     225     223     224
# 6    128    130    130      2      2     42    224     225     224     224
# 7    128    130    130      2      2     42    225     225     223     224
# 8    128    130    130      2      2     42    224     225     224     224
# 9    128    130    130      2      2     41    224     225     223     224
# 10   129    130    130      2      2     40    224     225     224     224
# 11   128    130    130      2      2     40    224     225     223     224
# 12   128    130    130      2      2     41    225     225     223     224
# 13   128    130    130      2      2     41    224     225     224     224
# 14   128    130    130      2      2     41    224     225     224     224
# 15   128    130    130      2      2     41    224     225     224     224
#
#     ...  KVARHT   KWHA   KWHB   KWHC  KWHT   FREQ   TEMP  SERRS  WRSSI  UPTIME
# 0   ...    5226  65493  37871  43054  5993 -32768  63768  -80.0    NaN     NaN
# 1   ...    5226  65493  37871  43055  5993 -32768  63771    NaN    NaN     NaN
# 2   ...    5226  65493  37871  43055  5993 -32768  63771    NaN    NaN     NaN
# 3   ...    5226  65493  37871  43055  5994 -32768  63773  -81.0    NaN     NaN
# 4   ...    5226  65493  37871  43055  5994 -32768  63774  -81.0    NaN     NaN
# 5   ...    5226  65493  37871  43055  5994 -32768  63775    NaN    NaN     NaN
# 6   ...    5226  65493  37872  43055  5994 -32768  63775  -81.0    NaN     NaN
# 7   ...    5226  65493  37872  43055  5995 -32768  63776  -81.0    NaN     NaN
# 8   ...    5226  65493  37872  43055  5994 -32768  63777  -81.0    NaN     NaN
# 9   ...    5226  65493  37872  43055  5994 -32768  63778  -82.0    NaN     NaN
# 10  ...    5226  65493  37872  43055  5994 -32768  63779  -80.0    NaN     NaN
# 11  ...    5226  65493  37872  43056  5994 -32768  63780  -81.0    NaN     NaN
# 12  ...    5226  65493  37872  43056  5994 -32768  63780  -80.0    NaN     NaN
# 13  ...    5226  65493  37872  43056  5994 -32768  63781  -80.0    NaN     NaN
# 14  ...    5226  65493  37872  43056  5993 -32768  63781  -80.0    NaN     NaN
# 15  ...    5226  65493  37872  43056  5993 -32768  63782  -80.0    NaN     NaN
#
# [16 rows x 40 columns]

# %%
#Printando somonte a coluna VARMS
dat[["VARMS","IARMS"]]
# Out:
#     VARMS  IARMS
# 0     130      2
# 1     130      2
# 2     130      2
# 3     130      2
# 4     130      2
# 5     130      2
# 6     130      2
# 7     130      2
# 8     130      2
# 9     130      2
# 10    130      2
# 11    130      2
# 12    130      2
# 13    130      2
# 14    130      2
# 15    130      2

# %%
# DESCRIBE: printa uma pequena analise, do Dataframe, como: Contagem, media, desvio padrao,minimo, percentil;25%;50%,75%, maximo
dat.describe()
# Out:
#              Time  VARMS  VBRMS  VCRMS  IARMS      IBRMS       ICRMS  VABRMS  \
# count   16.000000   16.0   16.0   16.0   16.0  16.000000   16.000000    16.0
# mean   128.125000  130.0  130.0    2.0    2.0  41.562500  224.187500   225.0
# std      0.341565    0.0    0.0    0.0    0.0   1.152895    0.403113     0.0
# min    128.000000  130.0  130.0    2.0    2.0  40.000000  224.000000   225.0
# 25%    128.000000  130.0  130.0    2.0    2.0  41.000000  224.000000   225.0
# 50%    128.000000  130.0  130.0    2.0    2.0  41.000000  224.000000   225.0
# 75%    128.000000  130.0  130.0    2.0    2.0  42.000000  224.000000   225.0
# max    129.000000  130.0  130.0    2.0    2.0  44.000000  225.000000   225.0
#
#            VBCRMS  VCARMS  ...  KVARHT     KWHA       KWHB         KWHC  \
# count   16.000000    16.0  ...    16.0     16.0     16.000     16.00000
# mean   223.437500   224.0  ...  5226.0  65493.0  37871.625  43055.25000
# std      0.512348     0.0  ...     0.0      0.0      0.500      0.57735
# min    223.000000   224.0  ...  5226.0  65493.0  37871.000  43054.00000
# 25%    223.000000   224.0  ...  5226.0  65493.0  37871.000  43055.00000
# 50%    223.000000   224.0  ...  5226.0  65493.0  37872.000  43055.00000
# 75%    224.000000   224.0  ...  5226.0  65493.0  37872.000  43056.00000
# max    224.000000   224.0  ...  5226.0  65493.0  37872.000  43056.00000
#
#              KWHT     FREQ          TEMP      SERRS  WRSSI  UPTIME
# count    16.00000     16.0     16.000000  13.000000    0.0     0.0
# mean   5993.75000 -32768.0  63776.312500 -80.615385    NaN     NaN
# std       0.57735      0.0      4.158826   0.650444    NaN     NaN
# min    5993.00000 -32768.0  63768.000000 -82.000000    NaN     NaN
# 25%    5993.00000 -32768.0  63773.750000 -81.000000    NaN     NaN
# 50%    5994.00000 -32768.0  63776.500000 -81.000000    NaN     NaN
# 75%    5994.00000 -32768.0  63780.000000 -80.000000    NaN     NaN
# max    5995.00000 -32768.0  63782.000000 -80.000000    NaN     NaN
#
# [8 rows x 40 columns]

# %%
#usando o matplot lab para plotar dados. 

# %matplotlib inline
dat[["VARMS","KVARHT"]].plot( LineWidth=3 )

# %% [markdown]
# # Fim do codigo funcional, abaixo só gamb

# %%
#Lendo daods contido no diretorio: C:/Users/Walgreen.melo/Desktop/Pydata/Green/Scripts/pw/Dados/dados.csv, 
#PS: AS BARRA FORAM INVERTIDOS PARA QUE FUNCIONE
datj = pd.read_json('C:/Users/Walgreen.melo/Desktop/Pydata/Green/Scripts/pw/Dados/BIN.json')
# Printando dados do data freme: dat
# Entre (), pode-se colocar a quantidade de linhas que se deseja printar.
# Numero em negrito ao lado, foram criado automaticamente pelo pandas; chamado de Id de linha. 
#https://www.youtube.com/watch?v=cd6eU5GV_8o
datj.head(20)
# Out:
#                                                  DATA  \
# 0   {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 130, 'IA...
# 1   {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 130, 'IA...
# 2   {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 130, 'IA...
# 3   {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 130, 'IA...
# 4   {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 130, 'IA...
# 5   {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 130, 'IA...
# 6   {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 130, 'IA...
# 7   {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 130, 'IA...
# 8   {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 129, 'IA...
# 9   {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 130, 'IA...
# 10  {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 130, 'IA...
# 11  {'VARMS': 129, 'VBRMS': 130, 'VCRMS': 130, 'IA...
# 12  {'VARMS': 129, 'VBRMS': 128, 'VCRMS': 131, 'IA...
# 13  {'VARMS': 129, 'VBRMS': 128, 'VCRMS': 130, 'IA...
# 14  {'VARMS': 129, 'VBRMS': 127, 'VCRMS': 131, 'IA...
# 15  {'VARMS': 129, 'VBRMS': 128, 'VCRMS': 131, 'IA...
# 16  {'VARMS': 129, 'VBRMS': 128, 'VCRMS': 130, 'IA...
# 17  {'VARMS': 129, 'VBRMS': 128, 'VCRMS': 130, 'IA...
# 18  {'VARMS': 130, 'VBRMS': 127, 'VCRMS': 130, 'IA...
# 19  {'VARMS': 130, 'VBRMS': 127, 'VCRMS': 130, 'IA...
#
#                                      _id
# 0   {'$oid': '5ede522e69de1e220a5a7c3b'}
# 1   {'$oid': '5ede522f69de1e220a5a7c3c'}
# 2   {'$oid': '5ede523069de1e220a5a7c3d'}
# 3   {'$oid': '5ede523369de1e220a5a7c3e'}
# 4   {'$oid': '5ede523469de1e220a5a7c3f'}
# 5   {'$oid': '5ede523569de1e220a5a7c40'}
# 6   {'$oid': '5ede523669de1e220a5a7c41'}
# 7   {'$oid': '5ede523769de1e220a5a7c42'}
# 8   {'$oid': '5ede523f69de1e220a5a7c43'}
# 9   {'$oid': '5ede524c69de1e220a5a7c44'}
# 10  {'$oid': '5ede52ce69de1e220a5a7c5b'}
# 11  {'$oid': '5ede55e069de1e220a5a7d46'}
# 12  {'$oid': '5ede563d69de1e220a5a7d82'}
# 13  {'$oid': '5ede563e69de1e220a5a7d84'}
# 14  {'$oid': '5ede564069de1e220a5a7d86'}
# 15  {'$oid': '5ede564169de1e220a5a7d88'}
# 16  {'$oid': '5ede564169de1e220a5a7d8a'}
# 17  {'$oid': '5ede564369de1e220a5a7d8c'}
# 18  {'$oid': '5ede564769de1e220a5a7d92'}
# 19  {'$oid': '5ede564869de1e220a5a7d94'}
